# %% [markdown]
# # Cleaning Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('cars.csv')

# %%
df = df.rename(index=str, columns={'mpg': 'mpg', 
                                   ' cylinders': 'cylinders', 
                                   ' cubicinches': 'cubicinches', 
                                   ' hp': 'hp', 
                                   ' weightlbs': 'weightlbs',  
                                   ' time-to-60': 'time_to_60', 
                                   ' year':'year', 
                                   ' brand': 'brand', })

# %%
X = df.copy()
X.drop(['brand', 'year'], axis=1, inplace=True)
X = X.convert_objects(convert_numeric=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time_to_60     0
# dtype: int64

# %%
X['cubicinches'].fillna(X['cubicinches'].median(), inplace=True)
X['weightlbs'].fillna(X['weightlbs'].median(), inplace=True)

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import scale

# %%
X = scale(X)

# %% [markdown]
# ### K-means

# %%
kmeans = KMeans(n_clusters=3, n_init=10, random_state=0) 
y_kmeans = kmeans.fit_predict(X)
#Дальше больше для себя из любопытства
d = {' Europe.': 0, ' Japan.': 1, ' US.': 2, }
y = df['brand'].apply(lambda x: d[x])
accuracy_score(y, y_kmeans)
######################################
# Out:
# 0.4789272030651341

# %%
def draw(k):
    X_temp = X #.values
    plt.scatter(X_temp[y_kmeans == 0, k], X_temp[y_kmeans == 0, k+1], s=100, c='blue')
    plt.scatter(X_temp[y_kmeans == 1, k], X_temp[y_kmeans == 1, k+1], s=100, c='green')
    plt.scatter(X_temp[y_kmeans == 2, k], X_temp[y_kmeans == 2, k+1], s=100, c='red')
    plt.scatter(kmeans.cluster_centers_[:, k], kmeans.cluster_centers_[:, k+1], s=300, c='yellow', label='Centroids')
    plt.title('Clusters of car brands')
    plt.legend()
    plt.show()

# %%
for i in range(5):
    draw(i)

# %% [markdown]
# ### Hierarchical clustering

# %%
agglo = AgglomerativeClustering(n_clusters=3) 
y_agglo = agglo.fit_predict(X)
#Дальше больше для себя из любопытства
d = {' Europe.': 2, ' Japan.': 0, ' US.': 1, }
y = df['brand'].apply(lambda x: d[x])
accuracy_score(y, y_agglo)
######################################
# Out:
# 0.4827586206896552

# %%
def draw(k):
    X_temp = X #.values
    plt.scatter(X_temp[y_agglo == 0, k], X_temp[y_agglo == 0, k+1], s=100, c='green')
    plt.scatter(X_temp[y_agglo == 1, k], X_temp[y_agglo == 1, k+1], s=100, c='red')
    plt.scatter(X_temp[y_agglo == 2, k], X_temp[y_agglo == 2, k+1], s=100, c='blue')
    plt.title('Clusters of car brands')
    plt.show()

# %%
for i in range(5):
    draw(i)

# %% [markdown]
# ### SVM

# %%
svm = SVC(gamma='auto', random_state=0)
cross_val_score(svm, X, y, cv=5, scoring='accuracy').mean()
# Out:
# 0.7626073909647716

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)

# %%
def draw(k):
    svm.fit(X_train, y_train)
    X_temp = X_test
    y_pred = svm.predict(X_test)
    plt.scatter(X_temp[y_pred == 0, k], X_temp[y_pred == 0, k+1], s=100, c='red', label='Japan')
    plt.scatter(X_temp[y_pred == 1, k], X_temp[y_pred == 1, k+1], s=100, c='green', label='US')
    plt.scatter(X_temp[y_pred == 2, k], X_temp[y_pred == 2, k+1], s=100, c='blue', label='Europe')
    plt.title('Clusters of car brands')
    plt.legend()
    plt.show()

# %%
for i in range(5):
    draw(i)
